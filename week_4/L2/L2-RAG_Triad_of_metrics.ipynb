# %% [markdown]
# # Lesson 2: RAG Triad of metrics

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import utils

print(f"LLM/embeddings via Gemini + local HF | API key loaded: {bool(utils.get_google_api_key())}")
# Out:
# LLM/embeddings via Gemini + local HF | API key loaded: True

# %%
import nest_asyncio

nest_asyncio.apply()

# %%
from llama_index.core import SimpleDirectoryReader

documents = SimpleDirectoryReader(
    input_files=["./eBook-How-to-Build-a-Career-in-AI.pdf"]
).load_data()

# %%
from llama_index.core import Document

document = Document(text="\n\n".join([doc.text for doc in documents]))

# %%
from utils import build_sentence_window_index
from llama_index.llms.google_genai import GoogleGenAI

llm = GoogleGenAI(
    model="gemma-4-31b-it",
    api_key=utils.get_google_api_key(),
    temperature=0.1,
)

sentence_index = build_sentence_window_index(
    document,
    llm,
    embed_model="local:BAAI/bge-small-en-v1.5",
    save_dir="sentence_index"
)
# Out:
# 2026-07-20 22:26:19,616 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it "HTTP/1.1 200 OK"
# 2026-07-20 22:26:20,005 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:20,040 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/modules.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:20,509 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:20,533 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:20,534 - INFO - Loading SentenceTransformer model from BAAI/bge-small-en-v1.5.
# 2026-07-20 22:26:20,822 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/config_sentence_transformers.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:20,845 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config_sentence_transformers.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:21,166 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/README.md "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:21,196 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/README.md "HTTP/1.1 200 OK"
# 2026-07-20 22:26:21,581 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:21,605 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/modules.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:21,884 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/sentence_bert_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:21,911 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/sentence_bert_config.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:22,236 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:22,604 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:22,628 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config.json "HTTP/1.1 200 OK"
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# 2026-07-20 22:26:23,016 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:23,499 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:23,932 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/video_preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:24,238 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:24,547 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:24,719 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:25,022 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:25,045 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:25,379 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:25,402 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/config.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:25,750 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:25,773 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:26,112 - INFO - HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-small-en-v1.5/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:26,390 - INFO - HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-small-en-v1.5/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-07-20 22:26:26,720 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-en-v1.5/resolve/main/1_Pooling/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:26,802 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-en-v1.5/5c38ec7c405ec4b44b94cc5a9bb96e735b38267a/1_Pooling%2Fconfig.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:27,112 - INFO - HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-small-en-v1.5 "HTTP/1.1 200 OK"
# 2026-07-20 22:26:27,400 - INFO - Loaded 1 prompt with these keys: ['query']
# 2026-07-20 22:26:27,716 - INFO - Loading all indices.

# %%
from utils import get_sentence_window_query_engine

sentence_window_engine = \
get_sentence_window_query_engine(sentence_index)
# Out:
# 2026-07-20 22:26:31,384 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/modules.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:31,387 - INFO - No modules.json found for BAAI/bge-reranker-base, initializing a new CrossEncoder model.
# 2026-07-20 22:26:31,664 - INFO - HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-reranker-base "HTTP/1.1 200 OK"
# 2026-07-20 22:26:32,128 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:32,151 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-reranker-base/2cfc18c9415c912f9d8155881c133215df768a70/config.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:32,439 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/adapter_config.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:32,718 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:32,742 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-reranker-base/2cfc18c9415c912f9d8155881c133215df768a70/config.json "HTTP/1.1 200 OK"
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# 2026-07-20 22:26:33,099 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/processor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:33,385 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:33,672 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/video_preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:33,971 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/preprocessor_config.json "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:34,282 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:34,304 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-reranker-base/2cfc18c9415c912f9d8155881c133215df768a70/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:34,583 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:34,665 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-reranker-base/2cfc18c9415c912f9d8155881c133215df768a70/config.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:34,964 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:34,989 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-reranker-base/2cfc18c9415c912f9d8155881c133215df768a70/config.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:35,273 - INFO - HTTP Request: HEAD https://huggingface.co/BAAI/bge-reranker-base/resolve/main/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# 2026-07-20 22:26:35,296 - INFO - HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-reranker-base/2cfc18c9415c912f9d8155881c133215df768a70/tokenizer_config.json "HTTP/1.1 200 OK"
# 2026-07-20 22:26:35,579 - INFO - HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-reranker-base/tree/main/additional_chat_templates?recursive=false&expand=false "HTTP/1.1 404 Not Found"
# 2026-07-20 22:26:35,862 - INFO - HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-reranker-base/tree/main?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-07-20 22:26:37,049 - INFO - HTTP Request: GET https://huggingface.co/api/models/BAAI/bge-reranker-base "HTTP/1.1 200 OK"

# %%
output = sentence_window_engine.query(
    "How do you create your AI portfolio?")
output.response
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:26:38,630 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:26:59,473 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 'You create an AI portfolio by building a portfolio of projects that shows skill progression, scoping successful AI projects, and finding projects that complement your career goals.'

# %% [markdown]
# ## RAG triad evaluators (LlamaIndex + Gemini)
#
# We score each answer with three LlamaIndex evaluators (judge = Gemini, temperature=0):
#
# 1. **Answer Relevancy** — does the answer address the question?
# 2. **Context Relevancy** — is retrieved context useful for the question?
# 3. **Groundedness (Faithfulness)** — is the answer supported by the retrieved context?
#
# Scores are in the range 0–1; higher is better.

# %%
# nest_asyncio already applied above
pass

# %%
from utils import get_eval_llm, get_rag_triad_evaluators

eval_llm = get_eval_llm()  # Gemini judge, temperature=0
evaluators = get_rag_triad_evaluators(llm=eval_llm)
evaluators
# Out:
# 2026-07-20 22:32:14,859 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it "HTTP/1.1 200 OK"
# {'answer_relevancy': <llama_index.core.evaluation.answer_relevancy.AnswerRelevancyEvaluator at 0x3847a3350>,
#  'context_relevancy': <llama_index.core.evaluation.context_relevancy.ContextRelevancyEvaluator at 0x386c311f0>,
#  'groundedness': <llama_index.core.evaluation.faithfulness.FaithfulnessEvaluator at 0x3847a1220>}

# %% [markdown]
# ### 1. Answer Relevancy

# %%
answer_relevancy = evaluators["answer_relevancy"]
answer_relevancy

# %% [markdown]
# ### 2. Context Relevancy

# %%
context_relevancy = evaluators["context_relevancy"]
context_relevancy

# %%
# Demo: score one answer + its retrieved contexts
sample_q = "How do you create your AI portfolio?"
sample_response = sentence_window_engine.query(sample_q)
sample_contexts = [n.node.get_content() for n in sample_response.source_nodes]

ar = answer_relevancy.evaluate(query=sample_q, response=str(sample_response))
cr = context_relevancy.evaluate(query=sample_q, contexts=sample_contexts)
print("Answer relevancy:", ar.score, ar.feedback)
print("Context relevancy:", cr.score, cr.feedback)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:32:20,302 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:32:39,934 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:32:39,947 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:32:53,272 - INFO - AFC is enabled with max remote calls: 10.
# Answer relevancy: 1.0 1. Does the provided response match the subject matter of the user's query?
# Yes. The user is asking about creating an AI portfolio, and the response specifically addresses the creation of an AI portfolio.
#
# 2. Does the provided response attempt to address the focus or perspective on the subject matter taken on by the user's query?
# Yes. The user is asking "how" to create the portfolio, and the response provides a high-level strategy (building a collection of projects that show skill progression) to achieve this. While the answer is very brief and lacks detailed steps, it does attempt to address the core of the query.
#
# [RESULT] 2
# Context relevancy: 0.25 1. **Does the retrieved context match the subject matter of the user's query?**
# The context is a list of chapter titles from a document. It mentions "Chapter 6: Building a Portfolio of Projects that Shows Skill Progression," which directly relates to the subject of creating an AI portfolio. However, because the context is only a table of contents and not the actual content of the chapter, it only identifies the location of the information rather than providing the subject matter itself.
# **Score: 1/2**
#
# 2. **Can the retrieved context be used exclusively to provide a full answer to the user's query?**
# No. The context provides only the titles of chapters. It does not contain any instructions, steps, or guidance on *how* to actually create an AI portfolio. A user cannot answer the query using only this list.
# **Score: 0/2**
#
# [RESULT] 1.0

# %%
pass  # context relevancy demo is in the previous cell

# %% [markdown]
# ### 3. Groundedness (Faithfulness)

# %%
groundedness = evaluators["groundedness"]
groundedness

# %%
fa = groundedness.evaluate_response(response=sample_response)
print("Groundedness:", fa.score, getattr(fa, "feedback", None) or fa.passing)
# Out:
# 2026-07-20 22:37:01,813 - INFO - AFC is enabled with max remote calls: 10.
# Groundedness: 1.0 YES

# %% [markdown]
# ## Evaluation of the RAG application

# %%
from utils import evaluate_query_engine, summarize_eval_df

# %%
eval_questions = []
with open("eval_questions.txt", "r") as file:
    for line in file:
        item = line.strip()
        if item:
            eval_questions.append(item)

# %%
eval_questions
# Out:
# ['What are the keys to building a career in AI?',
#  'How can teamwork contribute to success in AI?',
#  'What is the importance of networking in AI?',
#  'What are some good habits to develop for a successful career?',
#  'How can altruism be beneficial in building a career?',
#  'What is imposter syndrome and how does it relate to AI?',
#  'Who are some accomplished individuals who have experienced imposter syndrome?',
#  'What is the first step to becoming good at AI?',
#  'What are some common challenges in AI?',
#  'Is it normal to find parts of AI challenging?']

# %%
eval_questions.append("How can I be successful in AI?")

# %%
eval_questions
# Out:
# ['What are the keys to building a career in AI?',
#  'How can teamwork contribute to success in AI?',
#  'What is the importance of networking in AI?',
#  'What are some good habits to develop for a successful career?',
#  'How can altruism be beneficial in building a career?',
#  'What is imposter syndrome and how does it relate to AI?',
#  'Who are some accomplished individuals who have experienced imposter syndrome?',
#  'What is the first step to becoming good at AI?',
#  'What are some common challenges in AI?',
#  'Is it normal to find parts of AI challenging?',
#  'How can I be successful in AI?']

# %%
records = evaluate_query_engine(
    sentence_window_engine,
    eval_questions,
    app_id="sentence_window",
    llm=eval_llm,
    include_feedback=True,
)
records.head()
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:37:26,004 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:37:37,981 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:37:37,992 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:37:54,045 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:38:26,190 - INFO - AFC is enabled with max remote calls: 10.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:38:38,271 - ERROR - Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x107457800> is already entered
# 2026-07-20 22:38:38,272 - ERROR - Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x107457800> is already entered
# 2026-07-20 22:38:38,273 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:38:50,256 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:38:50,263 - ERROR - Task was destroyed but it is pending!
# task: <Task pending name='Task-149' coro=<_async_in_context.<locals>.run_in_context() done, defined at /Users/worawatlawanont/Projects/sut-ai-sw-dev/.venv/lib/python3.12/site-packages/ipykernel/utils.py:57> wait_for=<Task pending name='Task-150' coro=<Kernel.shell_main() running at /Users/worawatlawanont/Projects/sut-ai-sw-dev/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/worawatlawanont/Projects/sut-ai-sw-dev/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:563]>
# 2026-07-20 22:38:50,263 - ERROR - Task was destroyed but it is pending!
# task: <Task pending name='Task-150' coro=<Kernel.shell_main() running at /Users/worawatlawanont/Projects/sut-ai-sw-dev/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# 2026-07-20 22:38:50,264 - ERROR - Task was destroyed but it is pending!
# task: <Task pending name='Task-151' coro=<_async_in_context.<locals>.run_in_context() done, defined at /Users/worawatlawanont/Projects/sut-ai-sw-dev/.venv/lib/python3.12/site-packages/ipykernel/utils.py:57> wait_for=<Task pending name='Task-152' coro=<Kernel.shell_main() running at /Users/worawatlawanont/Projects/sut-ai-sw-dev/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/worawatlawanont/Projects/sut-ai-sw-dev/.venv/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:563]>
# 2026-07-20 22:38:50,264 - ERROR - Task was destroyed but it is pending!
# task: <Task pending name='Task-152' coro=<Kernel.shell_main() running at /Users/worawatlawanont/Projects/sut-ai-sw-dev/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# 2026-07-20 22:38:50,270 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:39:06,281 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:39:40,745 - INFO - AFC is enabled with max remote calls: 10.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:39:50,099 - ERROR - Exception in callback Task.__step()
# handle: <Handle Task.__step()>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# RuntimeError: cannot enter context: <_contextvars.Context object at 0x107457800> is already entered
# 2026-07-20 22:39:50,100 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:39:51,906 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 503 Service Unavailable"
# 2026-07-20 22:39:51,911 - WARNING - Retrying llama_index.llms.google_genai.base.GoogleGenAI._chat in 1 seconds as it raised ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}.
# 2026-07-20 22:39:52,921 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:40:03,382 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:40:03,404 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:40:22,230 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:40:55,498 - INFO - AFC is enabled with max remote calls: 10.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:41:13,149 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:41:21,270 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:41:21,273 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:41:49,202 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:42:17,468 - INFO - AFC is enabled with max remote calls: 10.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:42:25,658 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:42:32,860 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:42:32,870 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:43:05,612 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:43:28,180 - INFO - AFC is enabled with max remote calls: 10.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:43:37,635 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:43:47,891 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:43:47,897 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:44:01,755 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:44:19,288 - INFO - AFC is enabled with max remote calls: 10.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:44:35,920 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:44:43,666 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:44:43,672 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:44:55,376 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:45:10,778 - INFO - AFC is enabled with max remote calls: 10.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:45:20,917 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:45:48,158 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:45:48,193 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:46:18,160 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:46:37,829 - INFO - AFC is enabled with max remote calls: 10.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:47:03,464 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:47:19,398 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:47:19,405 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:47:31,518 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:47:59,247 - INFO - AFC is enabled with max remote calls: 10.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:48:13,246 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:48:20,166 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:48:20,171 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:48:32,239 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:48:56,243 - INFO - AFC is enabled with max remote calls: 10.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-07-20 22:49:04,578 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:49:22,329 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemma-4-31b-it:generateContent "HTTP/1.1 200 OK"
# 2026-07-20 22:49:22,336 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:49:37,636 - INFO - AFC is enabled with max remote calls: 10.
# 2026-07-20 22:50:00,320 - INFO - AFC is enabled with max remote calls: 10.
#             app_id                                           question  \
# 0  sentence_window      What are the keys to building a career in AI?
# 1  sentence_window      How can teamwork contribute to success in AI?
# 2  sentence_window        What is the importance of networking in AI?
# 3  sentence_window  What are some good habits to develop for a suc...
# 4  sentence_window  How can altruism be beneficial in building a c...
#
#                                               answer  answer_relevancy  \
# 0  The keys to building a career in AI include th...               1.0
# 1  Teamwork is required for larger AI projects, w...               1.0
# 2  Networking is particularly relevant in AI beca...               1.0
# 3  Successful people develop good habits in eatin...               1.0
# 4  People who aim to lift others during every ste...               0.5
#
#    context_relevancy  groundedness  \
# 0              0.750           1.0
# 1              0.750           1.0
# 2              0.625           1.0
# 3              0.750           1.0
# 4              0.625           1.0
#
#                            answer_relevancy_feedback  \
# 0  1. Does the provided response match the subjec...
# 1  1. Does the provided response match the subjec...
# 2  1. **Does the provided response match the subj...
# 3  1. Does the provided response match the subjec...
# 4  1. Does the provided response match the subjec...
#
#                           context_relevancy_feedback groundedness_feedback
# 0  **1. Does the retrieved context match the subj...                   YES
# 1  **1. Does the retrieved context match the subj...                   YES
# 2  1. **Does the retrieved context match the subj...                   YES
# 3  **1. Does the retrieved context match the subj...                   YES
# 4  1. **Does the retrieved context match the subj...                   YES

# %%
import pandas as pd

pd.set_option("display.max_colwidth", 120)
records[
    [
        "question",
        "answer_relevancy",
        "context_relevancy",
        "groundedness",
    ]
]

# %%
# Optional: inspect judge feedback for the first few rows
records[
    [
        "question",
        "answer_relevancy_feedback",
        "context_relevancy_feedback",
        "groundedness_feedback",
    ]
].head()

# %%
summarize_eval_df(records)

# %%
print("Done. Use summarize_eval_df(records) for mean triad scores.")
