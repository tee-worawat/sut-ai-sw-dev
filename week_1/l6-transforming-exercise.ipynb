# %% [markdown]
# # Exercise: Transforming
#
# Complete this notebook **after** working through `l6-transforming.ipynb`.
#
# You will practice using LLMs to **transform** text: translation, tone adjustment, format conversion, and proofreading.
#
# ---
#
# ## Setup
#
# Import the helper from `gemini_helpers.py` (same as the lesson notebook).

# %% [markdown]
# ---
#
# ## Exercise 1 — Basic Translation
#
# **Source text:**
#
# > Hi, I would like to order a standing desk.
#
# **Your task:**
#
# Write a prompt to translate the source text from English to **Japanese**. Use delimiters around the text.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 2 — Language Identification
#
# **Source text:**
#
# > Quanto costa la lampada da tavolo?
#
# **Your task:**
#
# Write a prompt asking the model to identify **which language** the text is written in.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 3 — Multi-Target Translation
#
# **Source text:**
#
# > I want to order a wireless keyboard.
#
# **Your task:**
#
# Write a prompt to translate the text into **German**, **Portuguese**, and **English pirate** (playful pirate dialect).
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 4 — Formal vs. Informal Translation
#
# **Source text:**
#
# > Would you like to order a coffee mug?
#
# **Your task:**
#
# Write a prompt to translate the sentence into **Spanish** in both **formal** and **informal** forms.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 5 — Universal Translator
#
# Your IT helpdesk receives messages in multiple languages. Use this list:
#
# ```python
# user_messages = [
#     "La impresora no imprime ningún documento.",
#     "Mein Bildschirm flackert ständig.",
#     "マイクが認識されません。",
# ]
# ```
#
# **Your task:**
#
# For each message, write prompts (in a loop) to:
# 1. Identify the language
# 2. Translate the message to **English** and **Thai**
#
# Print the original message, detected language, and translations.

# %% [markdown]
# ---
#
# ## Exercise 6 — Tone Transformation
#
# **Source text (casual/slang):**
#
# > Hey, it's Sam — check out this spec sheet for the new ergonomic chair, looks pretty solid.
#
# **Your task:**
#
# Write a prompt to rewrite the message as a **professional business email** suitable for a vendor.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 7 — Format Conversion (JSON to HTML)
#
# **Source data** — store in a variable called `data_json`:
#
# ```python
# data_json = {
#     "workshop attendees": [
#         {"name": "Anya", "email": "anya@example.com"},
#         {"name": "Ben", "email": "ben@example.com"},
#         {"name": "Chloe", "email": "chloe@example.com"}
#     ]
# }
# ```
#
# **Your task:**
#
# Write a prompt to convert the Python dictionary into an **HTML table** with column headers and a title.
#
# Print the response. Optionally display it with `IPython.display.HTML`.

# %% [markdown]
# ---
#
# ## Exercise 8 — Proofreading
#
# **Source texts** — store in a list called `texts`:
#
# ```python
# texts = [
#     "The team of engineers are ready for there review.",
#     "Its important to check you're work before submission.",
#     "This sentance is to test speling abilites.",
# ]
# ```
#
# **Your task:**
#
# Write a prompt template and loop over each string. Ask the model to **proofread and correct** the text. If there are no errors, it should say `"No errors found"`. Do not wrap the corrected text in extra punctuation.
#
# Print each original and corrected result.

# %% [markdown]
# ---
#
# ## Exercise 9 — Proofread and Improve a Review
#
# **Source text:**
#
# > got this backpack for school cuz my old one ripped. its roomy and the zippers work fine. one strap is shorter than the other tho which is weird. shipped fast, got it in 2 days. pretty good for what i payed.
#
# **Your task:**
#
# Write a prompt to **proofread, correct, and improve** this product review. Make it more compelling while keeping the same facts. Output in **markdown** format.
#
# Print or display the response.
