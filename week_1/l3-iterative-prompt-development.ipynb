# %% [markdown]
# # Iterative Prompt Development
# In this lesson, you'll iteratively analyze and refine your prompts to generate marketing copy from a product fact sheet.
#
# ## Setup

# %%
import sys
from pathlib import Path

for path in [Path.cwd(), Path.cwd() / "week_1"]:
    if (path / "gemini_helpers.py").exists():
        sys.path.insert(0, str(path))
        break

from gemini_helpers import get_completion

# %% [markdown]
# **Note**: Results may differ slightly from the original course videos, which used GPT models. The prompts are unchanged; only the underlying model is Gemini.

# %% [markdown]
# ## Generate a marketing product description from a product fact sheet

# %%
fact_sheet_chair = """
OVERVIEW
- Part of a beautiful family of mid-century inspired office furniture, 
including filing cabinets, desks, bookcases, meeting tables, and more.
- Several options of shell color and base finishes.
- Available with plastic back and front upholstery (SWC-100) 
or full upholstery (SWC-110) in 10 fabric and 6 leather options.
- Base finish options are: stainless steel, matte black, 
gloss white, or chrome.
- Chair is available with or without armrests.
- Suitable for home or business settings.
- Qualified for contract use.

CONSTRUCTION
- 5-wheel plastic coated aluminum base.
- Pneumatic chair adjust for easy raise/lower action.

DIMENSIONS
- WIDTH 53 CM | 20.87”
- DEPTH 51 CM | 20.08”
- HEIGHT 80 CM | 31.50”
- SEAT HEIGHT 44 CM | 17.32”
- SEAT DEPTH 41 CM | 16.14”

OPTIONS
- Soft or hard-floor caster options.
- Two choices of seat foam densities: 
 medium (1.8 lb/ft3) or high (2.8 lb/ft3)
- Armless or 8 position PU armrests 

MATERIALS
SHELL BASE GLIDER
- Cast Aluminum with modified nylon PA6/PA66 coating.
- Shell thickness: 10 mm.
SEAT
- HD36 foam

COUNTRY OF ORIGIN
- Italy
"""

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# ## Elevate Your Workspace: The Mid-Century Modern Task Chair
#
# Bring a touch of timeless Italian design to your office or home workspace with our versatile mid-century inspired task chair. Expertly crafted to blend aesthetic elegance with professional-grade durability, this chair is the perfect addition to any modern interior.
#
# **Tailored to Your Style**
# Make it your own with an extensive range of customization options. Choose between a sleek plastic back with front upholstery (SWC-100) or opt for the luxurious feel of full upholstery (SWC-110). With 10 premium fabric and 6 leather options, you can perfectly match your existing decor. Complete the look by selecting from four sophisticated base finishes: stainless steel, matte black, gloss white, or chrome.
#
# **Designed for Comfort and Performance**
# Engineered for both home and contract use, this chair features a robust 5-wheel, plastic-coated aluminum base for smooth mobility. Experience effortless comfort with our pneumatic height adjustment and your choice of medium or high-density seat foam. Whether you prefer a minimalist armless design or the ergonomic support of our 8-position PU armrests, this chair adapts to your unique needs.
#
# **Key Features:**
# *   **Italian Craftsmanship:** Designed and manufactured with precision in Italy.
# *   **Customizable Comfort:** Available with or without armrests and two foam density options.
# *   **Versatile Mobility:** Choose between soft or hard-floor casters to suit your workspace.
# *   **Durable Construction:** Features a 10mm thick cast aluminum shell with a high-quality nylon coating.
# *   **Professional Grade:** Fully qualified for contract use, ensuring long-lasting performance in high-traffic environments.
#
# **Dimensions:**
# *   **Width:** 53 cm (20.87”)
# *   **Depth:** 51 cm (20.08”)
# *   **Height:** 80 cm (31.50”)
# *   **Seat Height:** 44 cm (17.32”)
# *   **Seat Depth:** 41 cm (16.14”)
#
# **Upgrade your office with a chair that balances iconic mid-century style with the ergonomic support you need to stay productive all day long.**

# %% [markdown]
# ## Issue 1: The text is too long
# - Limit the number of words/sentences/characters.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# Elevate your workspace with this Italian-crafted, mid-century inspired office chair. Highly customizable, it features premium upholstery options, adjustable pneumatic height, and a durable aluminum base. Perfect for home or professional settings, this versatile chair combines timeless style with ergonomic comfort to suit any interior design.

# %%
len(response.split())
# Out:
# 45

# %% [markdown]
# ## Issue 2. Text focuses on the wrong details
# - Ask it to focus on the aspects that are relevant to the intended audience.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# This mid-century inspired office chair features a durable cast aluminum base with a nylon PA6/PA66 coating. Engineered for contract use, it includes HD36 seat foam, available in medium or high densities. Choose from various upholstery options, finishes, and armrest configurations to suit professional or residential environments. Made in Italy.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

Use at most 50 words.

Technical specifications: ```{fact_sheet_chair}```
"""
response = get_completion(prompt)
print(response)
# Out:
# This mid-century office chair features a durable cast aluminum base with a protective nylon PA6/PA66 coating. The 10mm shell supports high-density HD36 foam seating, available in various fabric or leather upholsteries. Designed for contract use, it includes pneumatic height adjustment and customizable caster options.
#
# Product IDs: SWC-100, SWC-110

# %% [markdown]
# ## Issue 3. Description needs a table of dimensions
# - Ask it to extract information and organize it in a table.

# %%
prompt = f"""
Your task is to help a marketing team create a 
description for a retail website of a product based 
on a technical fact sheet.

Write a product description based on the information 
provided in the technical specifications delimited by 
triple backticks.

The description is intended for furniture retailers, 
so should be technical in nature and focus on the 
materials the product is constructed from.

At the end of the description, include every 7-character 
Product ID in the technical specification.

After the description, include a table that gives the 
product's dimensions. The table should have two columns.
In the first column include the name of the dimension. 
In the second column include the measurements in inches only.

Give the table the title 'Product Dimensions'.

Format everything as HTML that can be used in a website. 
Place the description in a <div> element.

Technical specifications: ```{fact_sheet_chair}```
"""

response = get_completion(prompt)
print(response)
# Out:
# <div>
#     <h2>Mid-Century Professional Task Chair</h2>
#     <p>
#         Engineered for both residential and commercial contract environments, this mid-century inspired task chair combines structural integrity with refined aesthetics. The chair is constructed with a robust 5-wheel base manufactured from cast aluminum, finished with a durable, modified nylon PA6/PA66 coating for enhanced wear resistance. The structural shell features a 10 mm thickness, providing a stable foundation for long-term use.
#     </p>
#     <p>
#         The seating assembly is engineered for ergonomic support, utilizing high-density HD36 foam, with customizable density options of 1.8 lb/ft³ (medium) or 2.8 lb/ft³ (high). The chair features a pneumatic adjustment mechanism for precise height control. Clients may specify upholstery configurations ranging from plastic back with front upholstery to full upholstery in a selection of 10 fabrics or 6 leathers. Base finishes are available in stainless steel, matte black, gloss white, or chrome, with optional 8-position polyurethane armrests and specialized casters for either hard or soft flooring surfaces.
#     </p>
#     <p><strong>Product IDs:</strong> SWC-100, SWC-110</p>
# </div>
#
# <h3>Product Dimensions</h3>
# <table>
#     <thead>
#         <tr>
#             <th>Dimension</th>
#             <th>Measurement (Inches)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Width</td>
#             <td>20.87”</td>
#         </tr>
#         <tr>
#             <td>Depth</td>
#             <td>20.08”</td>
#         </tr>
#         <tr>
#             <td>Height</td>
#             <td>31.50”</td>
#         </tr>
#         <tr>
#             <td>Seat Height</td>
#             <td>17.32”</td>
#         </tr>
#         <tr>
#             <td>Seat Depth</td>
#             <td>16.14”</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Load Python libraries to view HTML

# %%
from IPython.display import display, HTML

# %%
display(HTML(response))
# Out:
# <div>
#     <h2>Mid-Century Professional Task Chair</h2>
#     <p>
#         Engineered for both residential and commercial contract environments, this mid-century inspired task chair combines structural integrity with refined aesthetics. The chair is constructed with a robust 5-wheel base manufactured from cast aluminum, finished with a durable, modified nylon PA6/PA66 coating for enhanced wear resistance. The structural shell features a 10 mm thickness, providing a stable foundation for long-term use.
#     </p>
#     <p>
#         The seating assembly is engineered for ergonomic support, utilizing high-density HD36 foam, with customizable density options of 1.8 lb/ft³ (medium) or 2.8 lb/ft³ (high). The chair features a pneumatic adjustment mechanism for precise height control. Clients may specify upholstery configurations ranging from plastic back with front upholstery to full upholstery in a selection of 10 fabrics or 6 leathers. Base finishes are available in stainless steel, matte black, gloss white, or chrome, with optional 8-position polyurethane armrests and specialized casters for either hard or soft flooring surfaces.
#     </p>
#     <p><strong>Product IDs:</strong> SWC-100, SWC-110</p>
# </div>
#
# <h3>Product Dimensions</h3>
# <table>
#     <thead>
#         <tr>
#             <th>Dimension</th>
#             <th>Measurement (Inches)</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>Width</td>
#             <td>20.87”</td>
#         </tr>
#         <tr>
#             <td>Depth</td>
#             <td>20.08”</td>
#         </tr>
#         <tr>
#             <td>Height</td>
#             <td>31.50”</td>
#         </tr>
#         <tr>
#             <td>Seat Height</td>
#             <td>17.32”</td>
#         </tr>
#         <tr>
#             <td>Seat Depth</td>
#             <td>16.14”</td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Try experimenting on your own!
