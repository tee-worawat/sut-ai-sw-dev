# %% [markdown]
# # Exercise: Inferring
#
# Complete this notebook **after** working through `l5-inferring.ipynb`.
#
# You will practice **inferring** sentiment, emotions, entities, and topics from text — often with tightly specified output formats.
#
# ---
#
# ## Setup
#
# Import the helper from `gemini_helpers.py` (same as the lesson notebook).

# %% [markdown]
# ---
#
# ## Source Material — Product Review
#
# Use this review for Exercises 1–6. Store it in a variable called `review`.
#
# > I bought the Aurora desk lamp for my home office because it has a built-in USB port and adjustable color temperature. It arrived quickly, but the base was cracked. BrightHome's support team shipped a replacement base within 48 hours at no charge. Assembly took ten minutes. BrightHome seems like a company that stands behind its products.

# %% [markdown]
# ---
#
# ## Exercise 1 — Sentiment (Open Answer)
#
# **Your task:**
#
# Write a prompt asking the model for the **sentiment** of the review (delimited with triple backticks). No format constraints yet.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 2 — Sentiment (Single Word)
#
# **Your task:**
#
# Refine your prompt so the model answers with a **single word**: either `positive` or `negative`.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 3 — Identify Emotions
#
# **Your task:**
#
# Write a prompt that identifies up to **five emotions** the reviewer is expressing. Format the answer as a list of **lower-case words separated by commas**.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 4 — Detect Anger
#
# **Your task:**
#
# Write a prompt asking whether the reviewer is expressing **anger**. Answer must be exactly `yes` or `no`.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 5 — Extract Item and Brand (JSON)
#
# **Your task:**
#
# Write a prompt to extract:
#
# - **Item** purchased by the reviewer
# - **Brand** (company that made the item)
#
# Return a **JSON object** with keys `"Item"` and `"Brand"`. Use `"unknown"` if information is missing. Keep the response as short as possible.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 6 — Multiple Inferences at Once
#
# **Your task:**
#
# Write **one prompt** that extracts all of the following in a single JSON object:
#
# - `Sentiment` — `positive` or `negative`
# - `Anger` — boolean (`true` or `false`)
# - `Item` — product purchased
# - `Brand` — company name
#
# Use `"unknown"` for missing string values. Print the response.

# %% [markdown]
# ---
#
# ## Exercise 7 — Infer Topics from a News Article
#
# **Source article** — store in a variable called `story`:
#
# > A city council report found that GreenLine Transit riders rated weekend service highest, with 88% satisfaction. Rider advocate Maria Chen said frequent bus arrivals on the new electric routes made travel easier. Transit director James Okoro welcomed the results and pledged more battery-electric buses next year. The report also noted complaints about late-night service in suburban zones, where satisfaction fell to 52%. Officials promised a pilot program for extended hours starting in autumn.
#
# **Your task:**
#
# Write a prompt to determine **five topics** discussed in the article. Each topic should be **one or two words**. Format as a **comma-separated list**.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 8 — Topic Alert System
#
# **Your task:**
#
# Given this topic list:
#
# ```python
# topic_list = [
#     "public transit",
#     "electric vehicles",
#     "city council",
#     "healthcare",
#     "rider satisfaction"
# ]
# ```
#
# Write a prompt that checks whether **each topic** appears in the article from Exercise 7. Format each line as:
#
# ```
# topic name: 0 or 1
# ```
#
# Parse the response and print `ALERT: New public transit story!` if the `public transit` topic scored `1`.
#
# *(You will need to write both the prompt and the parsing logic.)*
