# %% [markdown]
# # Exercise: Summarizing
#
# Complete this notebook **after** working through `l4-summarizing.ipynb`.
#
# You will practice summarizing product reviews with **different constraints and audiences** — and learn when to **extract** instead of summarize.
#
# ---
#
# ## Setup
#
# Import the helper from `gemini_helpers.py` (same as the lesson notebook).

# %% [markdown]
# ---
#
# ## Source Material — Product Review
#
# Use this review for Exercises 1–4. Store it in a variable called `prod_review`.
#
# > I ordered this stainless steel water bottle for my daily commute. It keeps drinks cold for hours and the matte finish looks great. However, the lid was scratched when it arrived and the box was dented on one corner. Customer support replaced the lid within three days, which I appreciated. Shipping was fast — it came two days after I ordered. For the price of $34, I expected slightly better packaging, but the bottle itself works well.

# %% [markdown]
# ---
#
# ## Exercise 1 — Summarize with a Word Limit
#
# **Your task:**
#
# Write a prompt that generates a short summary of the product review from an ecommerce site. Summarize the review (delimited by triple backticks) in **at most 30 words**.
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 2 — Summarize for the Shipping Department
#
# **Your task:**
#
# Write a prompt to summarize the review for the **Shipping department**. Requirements:
#
# - At most **30 words**
# - Focus only on aspects related to **shipping and delivery**
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 3 — Summarize for the Pricing Department
#
# **Your task:**
#
# Write a prompt to summarize the review for the **Pricing department** (the team that sets product prices). Requirements:
#
# - At most **30 words**
# - Focus only on **price and perceived value**
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 4 — Extract Instead of Summarize
#
# **Your task:**
#
# Rewrite your Shipping department prompt. This time, ask the model to **extract** (not summarize) only the information relevant to shipping and delivery. Limit to **30 words**.
#
# Compare mentally: does the output stay closer to the original facts than your Exercise 2 summary?
#
# Print the response.

# %% [markdown]
# ---
#
# ## Exercise 5 — Summarize Multiple Reviews
#
# Use these four reviews. Store them in a list called `reviews`.
#
# **Review A** (same water bottle review from above):
#
# > I ordered this stainless steel water bottle for my daily commute. It keeps drinks cold for hours and the matte finish looks great. However, the lid was scratched when it arrived and the box was dented on one corner. Customer support replaced the lid within three days, which I appreciated. Shipping was fast — it came two days after I ordered. For the price of $34, I expected slightly better packaging, but the bottle itself works well.
#
# **Review B** (wireless earbuds):
#
# > These earbuds paired instantly with my phone and the sound is clear for podcasts. Battery lasts about six hours per charge. The right earbud stopped connecting after two weeks. Support sent a replacement pair quickly. Arrived a day early in a plain envelope with no padding — luckily nothing was damaged.
#
# **Review C** (yoga mat):
#
# > Great grip and thickness for the price. I use it five times a week and it has not worn down. It had a strong rubber smell for the first few days. At $28 it feels like a solid deal compared to studio mats that cost twice as much.
#
# **Review D** (coffee grinder):
#
# > Grinds evenly and is quieter than my old blade grinder. The hopper is small so I refill often. Delivery took five business days even though I paid for express shipping. When I complained, the store refunded the express fee. Overall happy with the product, frustrated with shipping options.
#
# **Your task:**
#
# Write a prompt template and loop over all four reviews. For each review, generate a summary of **at most 20 words**. Print each summary with its index (0, 1, 2, 3).
